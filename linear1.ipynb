# %%
# Packages to use
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import  metrics

data = pd.read_csv('./iris_data.csv')

data = data.sample(frac=1, random_state=42).reset_index(drop=True)



data_x = data.iloc[:, :2]   #  x  sepal-length and sepal-width
data_y = data.iloc[:, 3]    #  y : petal Length

print(data_x)
print("data y below")
print(data_y)
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              6.1           2.8
# 1              5.7           3.8
# 2              7.7           2.6
# 3              6.0           2.9
# 4              6.8           2.8
# 5              5.4           3.4
# 6              5.6           2.9
# 7              6.9           3.1
# 8              6.2           2.2
# 9              5.8           2.7
# 10             6.5           3.2
# 11             4.8           3.0
# 12             5.5           3.5
# 13             4.9           3.1
# 14             5.1           3.8
# 15             6.3           3.3
# 16             6.5           3.0
# 17             5.6           2.5
# 18             5.7           2.8
# 19             6.4           2.8
# 20             4.7           3.2
# 21             6.1           3.0
# 22             5.0           3.4
# 23             6.4           2.8
# 24             7.9           3.8
# 25             6.7           3.0
# 26             6.7           2.5
# 27             6.8           3.2
# 28             4.8           3.0
# 29             4.8           3.1
# ..             ...           ...
# 120            6.1           3.0
# 121            4.5           2.3
# 122            6.6           2.9
# 123            5.5           2.6
# 124            5.3           3.7
# 125            5.6           3.0
# 126            7.3           2.9
# 127            6.7           3.3
# 128            5.1           3.7
# 129            4.9           2.4
# 130            6.7           3.3
# 131            7.2           3.0
# 132            4.9           3.1
# 133            6.7           3.1
# 134            4.9           3.0
# 135            6.9           3.1
# 136            7.4           2.8
# 137            6.3           2.9
# 138            5.7           2.8
# 139            6.5           3.0
# 140            6.3           2.3
# 141            6.4           2.9
# 142            5.6           2.8
# 143            5.9           3.0
# 144            5.4           3.4
# 145            6.1           2.8
# 146            4.9           2.5
# 147            5.8           4.0
# 148            5.8           2.6
# 149            7.1           3.0
#
# [150 rows x 2 columns]
# data y below
# 0      1.2
# 1      0.3
# 2      2.3
# 3      1.5
# 4      1.4
# 5      0.4
# 6      1.3
# 7      2.3
# 8      1.5
# 9      1.2
# 10     2.0
# 11     0.1
# 12     0.2
# 13     0.1
# 14     0.3
# 15     1.6
# 16     2.2
# 17     1.1
# 18     1.3
# 19     2.2
# 20     0.2
# 21     1.8
# 22     0.4
# 23     2.1
# 24     2.0
# 25     2.3
# 26     1.8
# 27     2.3
# 28     0.3
# 29     0.2
#       ...
# 120    1.4
# 121    0.3
# 122    1.3
# 123    1.2
# 124    0.2
# 125    1.3
# 126    1.8
# 127    2.1
# 128    0.4
# 129    1.0
# 130    2.5
# 131    1.6
# 132    0.1
# 133    2.4
# 134    0.2
# 135    1.5
# 136    1.9
# 137    1.8
# 138    1.3
# 139    1.8
# 140    1.3
# 141    1.3
# 142    2.0
# 143    1.8
# 144    0.2
# 145    1.3
# 146    1.7
# 147    0.2
# 148    1.2
# 149    2.1
# Name: PetalWidthCm, Length: 150, dtype: float64

# %%
scaler = StandardScaler()
scaler.fit(data_x)
data_x = scaler.transform(data_x)


# Getting the training data set and test data set
train_x, test_x,  train_y, test_y = train_test_split(data_x, data_y, test_size=0.33, shuffle=False)

lr = LinearRegression()     # create a linear regression model
lr.fit(train_x, train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predicted_y = lr.predict(test_x)

# print the actual and predicated side by side
df = pd.DataFrame({'Actual': np.array(test_y), 'Predicted': predicted_y})
print(df)
# Out:
#     Actual  Predicted
# 0      0.2   0.241416
# 1      0.3   0.416971
# 2      0.2   0.141880
# 3      1.5   1.795912
# 4      2.4   1.356193
# 5      0.3   0.094843
# 6      2.1   1.922609
# 7      2.5   1.405051
# 8      0.2   0.266756
# 9      1.4   1.452087
# 10     1.5   1.797733
# 11     1.8   1.575142
# 12     1.4   1.973288
# 13     2.3   1.528106
# 14     0.2   0.270398
# 15     2.1   1.947949
# 16     1.5   1.254836
# 17     2.0   1.700018
# 18     1.0   1.301872
# 19     1.4   0.882029
# 20     1.4   1.403230
# 21     0.3   0.558080
# 22     1.3   1.823073
# 23     1.2   1.153478
# 24     0.2   0.467650
# 25     1.3   1.032244
# 26     1.8   2.342452
# 27     2.1   1.701839
# 28     0.4   0.319256
# 29     1.0   0.806011
# 30     2.5   1.701839
# 31     1.6   2.219398
# 32     0.1   0.464007
# 33     2.4   1.799555
# 34     0.2   0.512865
# 35     1.5   1.947949
# 36     1.9   2.465507
# 37     1.8   1.600482
# 38     1.3   1.204157
# 39     1.8   1.700018
# 40     1.3   1.893627
# 41     1.3   1.674679
# 42     2.0   1.129960
# 43     1.8   1.254836
# 44     0.2   0.688420
# 45     1.3   1.500945
# 46     1.7   0.757153
# 47     0.2   0.692062
# 48     1.2   1.376069
# 49     2.1   2.145200

# %%
# plot a barchart of the values side by side
df.plot(figsize=(15, 7), kind='barh')
plt.show() # shows the bar graph


meanAbsError = metrics.mean_absolute_error(np.array(test_y), predicted_y)
meanSqrdError = metrics.mean_squared_error(np.array(test_y), predicted_y)
rootMeanSqrdError = np.sqrt(meanSqrdError)


print('Mean absolute error = ', meanAbsError)
print('Mean squared error = ', meanSqrdError)
print('Root mean squared error = ', rootMeanSqrdError)
# Out:
# Mean absolute error =  0.3604432768529388
# Mean squared error =  0.20481068752931397
# Root mean squared error =  0.4525601479685479
